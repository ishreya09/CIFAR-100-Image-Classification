# %%
import os

os.environ["KERAS_BACKEND"] = "jax" 

import keras
from keras import layers
from keras import ops

import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Paper link :-
# https://arxiv.org/abs/2010.11929

# %%
num_classes = 100
input_shape = (32, 32, 3)

(x_train, y_train), (x_test, y_test) = keras.datasets.cifar100.load_data()

print(f"x_train shape: {x_train.shape} - y_train shape: {y_train.shape}")
print(f"x_test shape: {x_test.shape} - y_test shape: {y_test.shape}")
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz
# 169001437/169001437 ━━━━━━━━━━━━━━━━━━━━ 3s 0us/step
# x_train shape: (50000, 32, 32, 3) - y_train shape: (50000, 1)
# x_test shape: (10000, 32, 32, 3) - y_test shape: (10000, 1)

# %% [markdown]
# ## Hyperparameters for model training

# %%
learning_rate = 0.001
weight_decay = 0.0001
batch_size = 256
num_epochs = 50  
image_size = 72  
patch_size = 6  # Size of the patches to be extract from the input images
num_patches = (image_size // patch_size) ** 2
projection_dim = 64
num_heads = 4
transformer_units = [
    projection_dim * 2,
    projection_dim,
]  # Size of the transformer layers
transformer_layers = 8
mlp_head_units = [
    2048,
    1024,
]  # Size of the dense layers of the final classifier

# %% [markdown]
# ## Data Augumentation

# %%
data_augmentation = keras.Sequential(
    [
        layers.Normalization(),
        layers.Resizing(image_size, image_size),
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(factor=0.02),
        layers.RandomZoom(height_factor=0.2, width_factor=0.2),
    ],
    name="data_augmentation",
)
# Compute the mean and the variance of the training data for normalization.
data_augmentation.layers[0].adapt(x_train)

# %%
def mlp(x, hidden_units, dropout_rate):
    for units in hidden_units:
        x = layers.Dense(units, activation=keras.activations.gelu)(x)
        x = layers.Dropout(dropout_rate)(x)
    return x

# %% [markdown]
# ## Implement patch creation as a layer

# %%
class Patches(layers.Layer):
    def __init__(self, patch_size):
        super().__init__()
        self.patch_size = patch_size

    def call(self, images):
        input_shape = ops.shape(images)
        batch_size = input_shape[0]
        height = input_shape[1]
        width = input_shape[2]
        channels = input_shape[3]
        num_patches_h = height // self.patch_size
        num_patches_w = width // self.patch_size
        patches = keras.ops.image.extract_patches(images, size=self.patch_size)
        patches = ops.reshape(
            patches,
            (
                batch_size,
                num_patches_h * num_patches_w,
                self.patch_size * self.patch_size * channels,
            ),
        )
        return patches

    def get_config(self):
        config = super().get_config()
        config.update({"patch_size": self.patch_size})
        return config

# %%
plt.figure(figsize=(4, 4))
image = x_train[np.random.choice(range(x_train.shape[0]))]
plt.imshow(image.astype("uint8"))
plt.axis("off")

resized_image = ops.image.resize(
    ops.convert_to_tensor([image]), size=(image_size, image_size)
)
patches = Patches(patch_size)(resized_image)
print(f"Image size: {image_size} X {image_size}")
print(f"Patch size: {patch_size} X {patch_size}")
print(f"Patches per image: {patches.shape[1]}")
print(f"Elements per patch: {patches.shape[-1]}")

n = int(np.sqrt(patches.shape[1]))
plt.figure(figsize=(4, 4))
for i, patch in enumerate(patches[0]):
    ax = plt.subplot(n, n, i + 1)
    patch_img = ops.reshape(patch, (patch_size, patch_size, 3))
    plt.imshow(ops.convert_to_numpy(patch_img).astype("uint8"))
    plt.axis("off")
# Out:
# Image size: 72 X 72
# Patch size: 6 X 6
# Patches per image: 144
# Elements per patch: 108

# %% [markdown]
# ## Implement the patch encoding layer
# The PatchEncoder layer will linearly transform a patch by projecting it into a vector of size projection_dim. In addition, it adds a learnable position embedding to the projected vector.

# %%
class PatchEncoder(layers.Layer):
    def __init__(self, num_patches, projection_dim):
        super().__init__()
        self.num_patches = num_patches
        self.projection = layers.Dense(units=projection_dim)
        self.position_embedding = layers.Embedding(
            input_dim=num_patches, output_dim=projection_dim
        )

    def call(self, patch):
        positions = ops.expand_dims(
            ops.arange(start=0, stop=self.num_patches, step=1), axis=0
        )
        projected_patches = self.projection(patch)
        encoded = projected_patches + self.position_embedding(positions)
        return encoded

    def get_config(self):
        config = super().get_config()
        config.update({"num_patches": self.num_patches})
        return config

# %% [markdown]
# ## Build the ViT model
# The ViT model consists of multiple Transformer blocks, which use the layers.MultiHeadAttention layer as a self-attention mechanism applied to the sequence of patches. The Transformer blocks produce a [batch_size, num_patches, projection_dim] tensor, which is processed via an classifier head with softmax to produce the final class probabilities output.
#
# Unlike the technique described in the paper, which prepends a learnable embedding to the sequence of encoded patches to serve as the image representation, all the outputs of the final Transformer block are reshaped with layers.Flatten() and used as the image representation input to the classifier head. Note that the layers.GlobalAveragePooling1D layer could also be used instead to aggregate the outputs of the Transformer block, especially when the number of patches and the projection dimensions are large.

# %%
def create_vit_classifier():
    inputs = keras.Input(shape=input_shape)
    # Augment data.
    augmented = data_augmentation(inputs)
    # Create patches.
    patches = Patches(patch_size)(augmented)
    # Encode patches.
    encoded_patches = PatchEncoder(num_patches, projection_dim)(patches)

    # Create multiple layers of the Transformer block.
    for _ in range(transformer_layers):
        # Layer normalization 1.
        x1 = layers.LayerNormalization(epsilon=1e-6)(encoded_patches)
        # Create a multi-head attention layer.
        attention_output = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=projection_dim, dropout=0.1
        )(x1, x1)
        # Skip connection 1.
        x2 = layers.Add()([attention_output, encoded_patches])
        # Layer normalization 2.
        x3 = layers.LayerNormalization(epsilon=1e-6)(x2)
        # MLP.
        x3 = mlp(x3, hidden_units=transformer_units, dropout_rate=0.1)
        # Skip connection 2.
        encoded_patches = layers.Add()([x3, x2])

    # Create a [batch_size, projection_dim] tensor.
    representation = layers.LayerNormalization(epsilon=1e-6)(encoded_patches)
    representation = layers.Flatten()(representation)
    representation = layers.Dropout(0.5)(representation)
    # Add MLP.
    features = mlp(representation, hidden_units=mlp_head_units, dropout_rate=0.5)
    # Classify outputs.
    logits = layers.Dense(num_classes)(features)
    # Create the Keras model.
    model = keras.Model(inputs=inputs, outputs=logits)
    return model

# %% [markdown]
# ## Compile, train, and evaluate the mode

# %%
def run_experiment(model):
    optimizer = keras.optimizers.AdamW(
        learning_rate=learning_rate, weight_decay=weight_decay
    )

    model.compile(
        optimizer=optimizer,
        loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
        metrics=[
            keras.metrics.SparseCategoricalAccuracy(name="accuracy"),
            keras.metrics.SparseTopKCategoricalAccuracy(5, name="top-5-accuracy"),
        ],
    )
    
    model.summary()

    checkpoint_filepath = "/tmp/checkpoint.weights.h5"
    checkpoint_callback = keras.callbacks.ModelCheckpoint(
        checkpoint_filepath,
        monitor="val_accuracy",
        save_best_only=True,
        save_weights_only=True,
    )
    
    history = model.fit(
        x=x_train,
        y=y_train,
        batch_size=batch_size,
        epochs=num_epochs,
        validation_split=0.1,
        callbacks=[checkpoint_callback],
    )

    model.load_weights(checkpoint_filepath)
    _, accuracy, top_5_accuracy = model.evaluate(x_test, y_test)
    print(f"Test accuracy: {round(accuracy * 100, 2)}%")
    print(f"Test top 5 accuracy: {round(top_5_accuracy * 100, 2)}%")
    
    
    
    # model.save("ViTModel.h5",save_format='tf')
    return history


vit_classifier = create_vit_classifier()
history = run_experiment(vit_classifier)


def plot_history(item):
    plt.plot(history.history[item], label=item)
    plt.plot(history.history["val_" + item], label="val_" + item)
    plt.xlabel("Epochs")
    plt.ylabel(item)
    plt.title("Train and Validation {} Over Epochs".format(item), fontsize=14)
    plt.legend()
    plt.grid()
    plt.show()


plot_history("loss")
plot_history("top-5-accuracy")
# Out:
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 32, 32, 3) │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ data_augmentation   │ (None, 72, 72, 3) │          7 │ input_layer[0][0] │
# │ (Sequential)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ patches_1 (Patches) │ (None, 144, 108)  │          0 │ data_augmentatio… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ patch_encoder       │ (None, 144, 64)   │     16,192 │ patches_1[0][0]   │
# │ (PatchEncoder)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalization │ (None, 144, 64)   │        128 │ patch_encoder[0]… │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 144, 64)   │     66,368 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 144, 64)   │          0 │ multi_head_atten… │
# │                     │                   │            │ patch_encoder[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 144, 64)   │        128 │ add[0][0]         │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 144, 128)  │      8,320 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 144, 128)  │          0 │ dense_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 144, 64)   │      8,256 │ dropout_1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 144, 64)   │          0 │ dense_2[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 144, 64)   │          0 │ dropout_2[0][0],  │
# │                     │                   │            │ add[0][0]         │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 144, 64)   │        128 │ add_1[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 144, 64)   │     66,368 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 144, 64)   │          0 │ multi_head_atten… │
# │                     │                   │            │ add_1[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 144, 64)   │        128 │ add_2[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 144, 128)  │      8,320 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, 144, 128)  │          0 │ dense_3[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_4 (Dense)     │ (None, 144, 64)   │      8,256 │ dropout_4[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_5 (Dropout) │ (None, 144, 64)   │          0 │ dense_4[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_3 (Add)         │ (None, 144, 64)   │          0 │ dropout_5[0][0],  │
# │                     │                   │            │ add_2[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 144, 64)   │        128 │ add_3[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 144, 64)   │     66,368 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_4 (Add)         │ (None, 144, 64)   │          0 │ multi_head_atten… │
# │                     │                   │            │ add_3[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 144, 64)   │        128 │ add_4[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_5 (Dense)     │ (None, 144, 128)  │      8,320 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_7 (Dropout) │ (None, 144, 128)  │          0 │ dense_5[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_6 (Dense)     │ (None, 144, 64)   │      8,256 │ dropout_7[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_8 (Dropout) │ (None, 144, 64)   │          0 │ dense_6[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_5 (Add)         │ (None, 144, 64)   │          0 │ dropout_8[0][0],  │
# │                     │                   │            │ add_4[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 144, 64)   │        128 │ add_5[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 144, 64)   │     66,368 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_6 (Add)         │ (None, 144, 64)   │          0 │ multi_head_atten… │
# │                     │                   │            │ add_5[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 144, 64)   │        128 │ add_6[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_7 (Dense)     │ (None, 144, 128)  │      8,320 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_10          │ (None, 144, 128)  │          0 │ dense_7[0][0]     │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_8 (Dense)     │ (None, 144, 64)   │      8,256 │ dropout_10[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_11          │ (None, 144, 64)   │          0 │ dense_8[0][0]     │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_7 (Add)         │ (None, 144, 64)   │          0 │ dropout_11[0][0], │
# │                     │                   │            │ add_6[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 144, 64)   │        128 │ add_7[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 144, 64)   │     66,368 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_8 (Add)         │ (None, 144, 64)   │          0 │ multi_head_atten… │
# │                     │                   │            │ add_7[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 144, 64)   │        128 │ add_8[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_9 (Dense)     │ (None, 144, 128)  │      8,320 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_13          │ (None, 144, 128)  │          0 │ dense_9[0][0]     │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_10 (Dense)    │ (None, 144, 64)   │      8,256 │ dropout_13[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_14          │ (None, 144, 64)   │          0 │ dense_10[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_9 (Add)         │ (None, 144, 64)   │          0 │ dropout_14[0][0], │
# │                     │                   │            │ add_8[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 144, 64)   │        128 │ add_9[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 144, 64)   │     66,368 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_10 (Add)        │ (None, 144, 64)   │          0 │ multi_head_atten… │
# │                     │                   │            │ add_9[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 144, 64)   │        128 │ add_10[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_11 (Dense)    │ (None, 144, 128)  │      8,320 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_16          │ (None, 144, 128)  │          0 │ dense_11[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_12 (Dense)    │ (None, 144, 64)   │      8,256 │ dropout_16[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_17          │ (None, 144, 64)   │          0 │ dense_12[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_11 (Add)        │ (None, 144, 64)   │          0 │ dropout_17[0][0], │
# │                     │                   │            │ add_10[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 144, 64)   │        128 │ add_11[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 144, 64)   │     66,368 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_12 (Add)        │ (None, 144, 64)   │          0 │ multi_head_atten… │
# │                     │                   │            │ add_11[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 144, 64)   │        128 │ add_12[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_13 (Dense)    │ (None, 144, 128)  │      8,320 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_19          │ (None, 144, 128)  │          0 │ dense_13[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_14 (Dense)    │ (None, 144, 64)   │      8,256 │ dropout_19[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_20          │ (None, 144, 64)   │          0 │ dense_14[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_13 (Add)        │ (None, 144, 64)   │          0 │ dropout_20[0][0], │
# │                     │                   │            │ add_12[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 144, 64)   │        128 │ add_13[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 144, 64)   │     66,368 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_14 (Add)        │ (None, 144, 64)   │          0 │ multi_head_atten… │
# │                     │                   │            │ add_13[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 144, 64)   │        128 │ add_14[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_15 (Dense)    │ (None, 144, 128)  │      8,320 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_22          │ (None, 144, 128)  │          0 │ dense_15[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_16 (Dense)    │ (None, 144, 64)   │      8,256 │ dropout_22[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_23          │ (None, 144, 64)   │          0 │ dense_16[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_15 (Add)        │ (None, 144, 64)   │          0 │ dropout_23[0][0], │
# │                     │                   │            │ add_14[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 144, 64)   │        128 │ add_15[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten (Flatten)   │ (None, 9216)      │          0 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_24          │ (None, 9216)      │          0 │ flatten[0][0]     │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_17 (Dense)    │ (None, 2048)      │ 18,876,416 │ dropout_24[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_25          │ (None, 2048)      │          0 │ dense_17[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_18 (Dense)    │ (None, 1024)      │  2,098,176 │ dropout_25[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_26          │ (None, 1024)      │          0 │ dense_18[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_19 (Dense)    │ (None, 100)       │    102,500 │ dropout_26[0][0]  │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 21,759,019 (83.00 MB)
#  Trainable params: 21,759,012 (83.00 MB)
#  Non-trainable params: 7 (28.00 B)
# Epoch 1/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 398s 2s/step - accuracy: 0.0309 - loss: 4.8866 - top-5-accuracy: 0.1179 - val_accuracy: 0.1112 - val_loss: 3.9002 - val_top-5-accuracy: 0.3136
# Epoch 2/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 354s 2s/step - accuracy: 0.0828 - loss: 4.0211 - top-5-accuracy: 0.2658 - val_accuracy: 0.1586 - val_loss: 3.5969 - val_top-5-accuracy: 0.4110
# Epoch 3/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 356s 2s/step - accuracy: 0.1218 - loss: 3.7510 - top-5-accuracy: 0.3468 - val_accuracy: 0.1824 - val_loss: 3.4057 - val_top-5-accuracy: 0.4464
# Epoch 4/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 357s 2s/step - accuracy: 0.1535 - loss: 3.5406 - top-5-accuracy: 0.4082 - val_accuracy: 0.2292 - val_loss: 3.2098 - val_top-5-accuracy: 0.5184
# Epoch 5/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 353s 2s/step - accuracy: 0.1825 - loss: 3.3929 - top-5-accuracy: 0.4505 - val_accuracy: 0.2458 - val_loss: 3.0693 - val_top-5-accuracy: 0.5426
# Epoch 6/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 353s 2s/step - accuracy: 0.2024 - loss: 3.2578 - top-5-accuracy: 0.4879 - val_accuracy: 0.2690 - val_loss: 2.9583 - val_top-5-accuracy: 0.5690
# Epoch 7/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 354s 2s/step - accuracy: 0.2306 - loss: 3.1291 - top-5-accuracy: 0.5209 - val_accuracy: 0.2826 - val_loss: 2.8524 - val_top-5-accuracy: 0.5898
# Epoch 8/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 353s 2s/step - accuracy: 0.2527 - loss: 3.0163 - top-5-accuracy: 0.5548 - val_accuracy: 0.3050 - val_loss: 2.7851 - val_top-5-accuracy: 0.6058
# Epoch 9/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 349s 2s/step - accuracy: 0.2706 - loss: 2.9472 - top-5-accuracy: 0.5688 - val_accuracy: 0.3284 - val_loss: 2.6520 - val_top-5-accuracy: 0.6292
# Epoch 10/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 350s 2s/step - accuracy: 0.2963 - loss: 2.8025 - top-5-accuracy: 0.6027 - val_accuracy: 0.3496 - val_loss: 2.5732 - val_top-5-accuracy: 0.6560
# Epoch 11/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 354s 2s/step - accuracy: 0.3067 - loss: 2.7355 - top-5-accuracy: 0.6199 - val_accuracy: 0.3570 - val_loss: 2.5323 - val_top-5-accuracy: 0.6588
# Epoch 12/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 351s 2s/step - accuracy: 0.3268 - loss: 2.6353 - top-5-accuracy: 0.6427 - val_accuracy: 0.3680 - val_loss: 2.4567 - val_top-5-accuracy: 0.6756
# Epoch 13/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 351s 2s/step - accuracy: 0.3449 - loss: 2.5561 - top-5-accuracy: 0.6607 - val_accuracy: 0.3816 - val_loss: 2.3923 - val_top-5-accuracy: 0.6944
# Epoch 14/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 350s 2s/step - accuracy: 0.3560 - loss: 2.4846 - top-5-accuracy: 0.6762 - val_accuracy: 0.3978 - val_loss: 2.3334 - val_top-5-accuracy: 0.7006
# Epoch 15/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 349s 2s/step - accuracy: 0.3809 - loss: 2.3795 - top-5-accuracy: 0.6955 - val_accuracy: 0.3956 - val_loss: 2.3181 - val_top-5-accuracy: 0.7016
# Epoch 16/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 350s 2s/step - accuracy: 0.3978 - loss: 2.3235 - top-5-accuracy: 0.7110 - val_accuracy: 0.4272 - val_loss: 2.2322 - val_top-5-accuracy: 0.7210
# Epoch 17/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 350s 2s/step - accuracy: 0.4057 - loss: 2.2803 - top-5-accuracy: 0.7195 - val_accuracy: 0.4234 - val_loss: 2.2258 - val_top-5-accuracy: 0.7218
# Epoch 18/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 351s 2s/step - accuracy: 0.4182 - loss: 2.2289 - top-5-accuracy: 0.7254 - val_accuracy: 0.4294 - val_loss: 2.1724 - val_top-5-accuracy: 0.7324
# Epoch 19/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 351s 2s/step - accuracy: 0.4239 - loss: 2.1743 - top-5-accuracy: 0.7436 - val_accuracy: 0.4384 - val_loss: 2.1577 - val_top-5-accuracy: 0.7298
# Epoch 20/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 353s 2s/step - accuracy: 0.4361 - loss: 2.1116 - top-5-accuracy: 0.7539 - val_accuracy: 0.4486 - val_loss: 2.1180 - val_top-5-accuracy: 0.7422
# Epoch 21/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 357s 2s/step - accuracy: 0.4492 - loss: 2.0502 - top-5-accuracy: 0.7645 - val_accuracy: 0.4534 - val_loss: 2.0900 - val_top-5-accuracy: 0.7534
# Epoch 22/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 355s 2s/step - accuracy: 0.4666 - loss: 1.9870 - top-5-accuracy: 0.7777 - val_accuracy: 0.4604 - val_loss: 2.0686 - val_top-5-accuracy: 0.7514
# Epoch 23/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 354s 2s/step - accuracy: 0.4737 - loss: 1.9476 - top-5-accuracy: 0.7828 - val_accuracy: 0.4716 - val_loss: 2.0119 - val_top-5-accuracy: 0.7634
# Epoch 24/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 353s 2s/step - accuracy: 0.4766 - loss: 1.9294 - top-5-accuracy: 0.7858 - val_accuracy: 0.4586 - val_loss: 2.0668 - val_top-5-accuracy: 0.7528
# Epoch 25/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 354s 2s/step - accuracy: 0.4919 - loss: 1.8683 - top-5-accuracy: 0.7975 - val_accuracy: 0.4724 - val_loss: 2.0011 - val_top-5-accuracy: 0.7676
# Epoch 26/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 354s 2s/step - accuracy: 0.5013 - loss: 1.8348 - top-5-accuracy: 0.8028 - val_accuracy: 0.4700 - val_loss: 2.0183 - val_top-5-accuracy: 0.7632
# Epoch 27/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 355s 2s/step - accuracy: 0.5077 - loss: 1.7958 - top-5-accuracy: 0.8100 - val_accuracy: 0.4884 - val_loss: 1.9856 - val_top-5-accuracy: 0.7708
# Epoch 28/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 360s 2s/step - accuracy: 0.5186 - loss: 1.7489 - top-5-accuracy: 0.8185 - val_accuracy: 0.4890 - val_loss: 1.9693 - val_top-5-accuracy: 0.7690
# Epoch 29/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 358s 2s/step - accuracy: 0.5250 - loss: 1.7258 - top-5-accuracy: 0.8261 - val_accuracy: 0.4930 - val_loss: 1.9438 - val_top-5-accuracy: 0.7778
# Epoch 30/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 355s 2s/step - accuracy: 0.5344 - loss: 1.6783 - top-5-accuracy: 0.8300 - val_accuracy: 0.4908 - val_loss: 1.9591 - val_top-5-accuracy: 0.7818
# Epoch 31/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 355s 2s/step - accuracy: 0.5435 - loss: 1.6486 - top-5-accuracy: 0.8375 - val_accuracy: 0.4954 - val_loss: 1.9418 - val_top-5-accuracy: 0.7852
# Epoch 32/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 355s 2s/step - accuracy: 0.5465 - loss: 1.6349 - top-5-accuracy: 0.8424 - val_accuracy: 0.5046 - val_loss: 1.9177 - val_top-5-accuracy: 0.7818
# Epoch 33/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 353s 2s/step - accuracy: 0.5502 - loss: 1.6041 - top-5-accuracy: 0.8454 - val_accuracy: 0.5016 - val_loss: 1.9329 - val_top-5-accuracy: 0.7858
# Epoch 34/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 354s 2s/step - accuracy: 0.5615 - loss: 1.5704 - top-5-accuracy: 0.8489 - val_accuracy: 0.5050 - val_loss: 1.9083 - val_top-5-accuracy: 0.7842
# Epoch 35/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 354s 2s/step - accuracy: 0.5695 - loss: 1.5260 - top-5-accuracy: 0.8606 - val_accuracy: 0.4982 - val_loss: 1.9367 - val_top-5-accuracy: 0.7862
# Epoch 36/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 354s 2s/step - accuracy: 0.5734 - loss: 1.5186 - top-5-accuracy: 0.8602 - val_accuracy: 0.4966 - val_loss: 1.9302 - val_top-5-accuracy: 0.7868
# Epoch 37/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 354s 2s/step - accuracy: 0.5776 - loss: 1.4980 - top-5-accuracy: 0.8617 - val_accuracy: 0.5084 - val_loss: 1.9465 - val_top-5-accuracy: 0.7844
# Epoch 38/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 354s 2s/step - accuracy: 0.5907 - loss: 1.4565 - top-5-accuracy: 0.8705 - val_accuracy: 0.5130 - val_loss: 1.8960 - val_top-5-accuracy: 0.7936
# Epoch 39/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 354s 2s/step - accuracy: 0.5953 - loss: 1.4312 - top-5-accuracy: 0.8722 - val_accuracy: 0.5048 - val_loss: 1.9288 - val_top-5-accuracy: 0.7876
# Epoch 40/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 354s 2s/step - accuracy: 0.6035 - loss: 1.4042 - top-5-accuracy: 0.8789 - val_accuracy: 0.5168 - val_loss: 1.9009 - val_top-5-accuracy: 0.7892
# Epoch 41/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 352s 2s/step - accuracy: 0.6080 - loss: 1.3839 - top-5-accuracy: 0.8793 - val_accuracy: 0.5014 - val_loss: 1.9476 - val_top-5-accuracy: 0.7844
# Epoch 42/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 352s 2s/step - accuracy: 0.6094 - loss: 1.3714 - top-5-accuracy: 0.8838 - val_accuracy: 0.5080 - val_loss: 1.9306 - val_top-5-accuracy: 0.7882
# Epoch 43/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 352s 2s/step - accuracy: 0.6153 - loss: 1.3464 - top-5-accuracy: 0.8876 - val_accuracy: 0.5136 - val_loss: 1.9103 - val_top-5-accuracy: 0.7948
# Epoch 44/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 351s 2s/step - accuracy: 0.6229 - loss: 1.3168 - top-5-accuracy: 0.8942 - val_accuracy: 0.5052 - val_loss: 1.9330 - val_top-5-accuracy: 0.7934
# Epoch 45/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 352s 2s/step - accuracy: 0.6202 - loss: 1.3177 - top-5-accuracy: 0.8917 - val_accuracy: 0.5036 - val_loss: 1.9894 - val_top-5-accuracy: 0.7836
# Epoch 46/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 351s 2s/step - accuracy: 0.6282 - loss: 1.2881 - top-5-accuracy: 0.8938 - val_accuracy: 0.5114 - val_loss: 1.9039 - val_top-5-accuracy: 0.7940
# Epoch 47/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 356s 2s/step - accuracy: 0.6352 - loss: 1.2683 - top-5-accuracy: 0.8985 - val_accuracy: 0.5230 - val_loss: 1.8897 - val_top-5-accuracy: 0.7992
# Epoch 48/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 359s 2s/step - accuracy: 0.6424 - loss: 1.2403 - top-5-accuracy: 0.9023 - val_accuracy: 0.5162 - val_loss: 1.9677 - val_top-5-accuracy: 0.7846
# Epoch 49/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 358s 2s/step - accuracy: 0.6478 - loss: 1.2250 - top-5-accuracy: 0.9036 - val_accuracy: 0.5128 - val_loss: 1.9384 - val_top-5-accuracy: 0.7916
# Epoch 50/50
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 352s 2s/step - accuracy: 0.6453 - loss: 1.2223 - top-5-accuracy: 0.9081 - val_accuracy: 0.5248 - val_loss: 1.8861 - val_top-5-accuracy: 0.8012
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 58s 171ms/step - accuracy: 0.5232 - loss: 1.8758 - top-5-accuracy: 0.8009
# Test accuracy: 52.63%
# Test top 5 accuracy: 80.39%
